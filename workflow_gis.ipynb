# %%
import lasio
import pandas as pd
import numpy as np
from qa_qc_lib.qa_qc_gis import QA_QC_gis

# %%
las_path = 'data/59P_OK_ft.las'
gis_qa_qc = QA_QC_gis(las_path)
# Out:
# ВНИМАНИЕ! Не удалось распознать следующие каротажи: ['GZ1', 'GZ2', 'GZ3', 'GZ3R', 'GZ4', 'LLD', 'PZ']
#
#           Для того чтобы эти каротажи учавствовали в дальнейших тестах, следует расширить словарь мненмоник (используйте метод add_mnemonics),
#           а затем снова провести проверку, используя метод check_gis_names, чтобы список unidentified_gis сформировался заново.

# %%
list_of_tests = gis_qa_qc.get_list_of_tests()
list_of_tests
# Out:
# ['test_physical_correctness']

# %%
gis_qa_qc.add_mnemonics('SP', ['Shaitan_kyterma'])
gis_qa_qc.return_mnemonics()
# Out:
# {'SP': ['SP', 'PS', 'ПС', 'СП', 'PS_1', 'PS_2', 'Shaitan_kyterma'],
#  'GR': ['GR', 'GK', 'ГК', 'ECGR', 'GK_1', 'GK_2'],
#  'DS': ['DS', 'CALI', 'HCAL', 'CALIP', 'DCAV', 'DSN', 'DS_1', 'DS2'],
#  'MDS': ['MCAL', 'MDS'],
#  'MINV': ['МГЗ', 'MGZ'],
#  'MNOR': ['МПЗ', 'MPZ'],
#  'MLL': ['MLL', 'MBK', 'МБК', 'МКЗ', 'MSFL', 'RXOZ'],
#  'RHOB': ['RHOB', 'PL', 'GGKP', 'RHOZ', 'DRHB', 'ROBB'],
#  'PEF': ['PEF', 'PE', 'PEFZ', 'ZEFF'],
#  'DT': ['AK', 'DT', 'DTp', 'DTP', 'АК', 'AK_2', 'DTL', 'DTS', 'DTP1'],
#  'ILD': ['IK', 'ILD', 'ИК', 'CILD', 'IKA', 'ILDA', 'IK_1', 'R27PC_46PH'],
#  'ILDR': ['IKR', 'ILDR'],
#  'VIKIZ': ['ВИКИЗ',
#   'VIKIZ',
#   'F05',
#   'F07',
#   'F10',
#   'F14',
#   'F20',
#   'R05',
#   'R07',
#   'R10',
#   'R14',
#   'R20',
#   'С05',
#   'С07',
#   'С10',
#   'С14',
#   'С20',
#   'AT10',
#   'AT20',
#   'AT30',
#   'AT60',
#   'AT90',
#   'AF10',
#   'AF20',
#   'AF30',
#   'AF60',
#   'AF90',
#   'ILDVG1',
#   'ILDVG2',
#   'ILDVG3',
#   'ILDVG4',
#   'ILDVG5',
# ...

# %%
gis_qa_qc.remove_mnemonics('SP', ['Shaitan_kyterma', 'PS_2'])
gis_qa_qc.return_mnemonics()
# Out:
# {'SP': ['SP', 'PS', 'ПС', 'СП', 'PS_1'],
#  'GR': ['GR', 'GK', 'ГК', 'ECGR', 'GK_1', 'GK_2'],
#  'DS': ['DS', 'CALI', 'HCAL', 'CALIP', 'DCAV', 'DSN', 'DS_1', 'DS2'],
#  'MDS': ['MCAL', 'MDS'],
#  'MINV': ['МГЗ', 'MGZ'],
#  'MNOR': ['МПЗ', 'MPZ'],
#  'MLL': ['MLL', 'MBK', 'МБК', 'МКЗ', 'MSFL', 'RXOZ'],
#  'RHOB': ['RHOB', 'PL', 'GGKP', 'RHOZ', 'DRHB', 'ROBB'],
#  'PEF': ['PEF', 'PE', 'PEFZ', 'ZEFF'],
#  'DT': ['AK', 'DT', 'DTp', 'DTP', 'АК', 'AK_2', 'DTL', 'DTS', 'DTP1'],
#  'ILD': ['IK', 'ILD', 'ИК', 'CILD', 'IKA', 'ILDA', 'IK_1', 'R27PC_46PH'],
#  'ILDR': ['IKR', 'ILDR'],
#  'VIKIZ': ['ВИКИЗ',
#   'VIKIZ',
#   'F05',
#   'F07',
#   'F10',
#   'F14',
#   'F20',
#   'R05',
#   'R07',
#   'R10',
#   'R14',
#   'R20',
#   'С05',
#   'С07',
#   'С10',
#   'С14',
#   'С20',
#   'AT10',
#   'AT20',
#   'AT30',
#   'AT60',
#   'AT90',
#   'AF10',
#   'AF20',
#   'AF30',
#   'AF60',
#   'AF90',
#   'ILDVG1',
#   'ILDVG2',
#   'ILDVG3',
#   'ILDVG4',
#   'ILDVG5',
#   'ILDVR1',
#   'ILDVR2',
# ...

# %%
gis_qa_qc.remove_mnemonics('Sk', ['Shaitan_kyterma', 'PS_2'])
gis_qa_qc.return_mnemonics()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 gis_qa_qc.remove_mnemonics('Sk', ['Shaitan_kyterma', 'PS_2'])
#       2 gis_qa_qc.return_mnemonics()
#
# File c:\Users\SalnikovMA\PycharmProjects\QA_QC_proj\QA_QC_proj-qaqcgis\qa_qc_lib\qa_qc_gis.py:77, in QA_QC_gis.remove_mnemonics(self, key, values_to_remove)
#      75 key = key.upper()
#      76  # Проверяем, есть ли ключ в словаре с помощью assert
# ---> 77 assert key in self.__mnemonics, f"Key '{key}' not found in mnemonics dictionary"
#      79 # Удаляем каждое значение из списка, связанного с ключом
#      80 for value in values_to_remove:
#
# AssertionError: Key 'SK' not found in mnemonics dictionary

# %%
result = gis_qa_qc.start_tests(list_of_tests)
# Out:
#      Тест пройден успешно.
#      Значения коротажа DS физически корректны
#
#      Тест не пройден.
#      Неизвестная размерность данных ms/m для DT
#
#      Тест пройден успешно.
#      Значения коротажа GR физически корректны (Внимание, для этого ГИС проводилась проверка только на положительность значений)
#
#      Тест пройден успешно.
#      Значения коротажа ILD физически корректны (Внимание, для этого ГИС проводилась проверка только на положительность значений)
#
#      Тест пройден успешно.
#      Значения коротажа MGZ физически корректны (Внимание, для этого ГИС проводилась проверка только на положительность значений)
#
#      Тест пройден успешно.
#      Значения коротажа MPZ физически корректны (Внимание, для этого ГИС проводилась проверка только на положительность значений)
#
#      Тест пройден успешно.
#      Значения коротажа NKTD физически корректны (Внимание, для этого ГИС проводилась проверка только на положительность значений)
#
#      Тест пройден успешно.
# ...

# %%
result
# Out:
# {'test_physical_correctness': {'DS': {'test_result_mask': [True,
#     True,
#     True,
#     True,
#     True,
#     True,
#     True,
#     True,
#     True,
#     True,
#     True,
#     True,
#     True,
#     True,
#     True,
#     True,
#     True,
#     True,
#     True,
#     True,
#     True,
#     True,
#     True,
#     True,
#     True,
#     True,
#     True,
#     True,
#     True,
#     True,
#     True,
#     True,
#     True,
#     True,
#     True,
#     True,
#     True,
#     True,
#     True,
#     True,
#     True,
#     True,
#     True,
#     True,
#     True,
#     True,
#     True,
#     True,
#     True,
#     True,
#     True,
#     True,
#     True,
#     True,
#     True,
#     True,
#     True,
#     True,
#     True,
#     True,
#     True,
#     True,
#     True,
#     True,
#     True,
#     True,
#     True,
#     True,
#     True,
#     True,
#     True,
#     True,
#     True,
#     True,
#     True,
#     True,
#     True,
#     True,
# ...

# %%
gis_qa_qc.generate_test_report()
