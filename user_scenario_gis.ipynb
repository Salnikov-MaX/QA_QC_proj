# %%
from qa_qc_lib.qa_qc_gis import QA_QC_gis
from qa_qc_lib.gis_second_test_functions import *

# %%
las_path = 'data/gis_data/59P_OK_ft.las'
gis_qa_qc = QA_QC_gis(las_path = las_path,
                      well_tops_path='data/gis_data/well_tops.xlsx'
                      )
# Out:
# ВНИМАНИЕ! Не удалось распознать следующие каротажи: ['GZ1', 'GZ2', 'GZ3', 'GZ3R', 'GZ4', 'LLD', 'PZ']
#
#           Для того чтобы эти каротажи учавствовали в дальнейших тестах, следует расширить словарь мненмоник (используйте метод add_mnemonics),
#           а затем снова провести проверку, используя метод check_gis_names, чтобы список unidentified_gis сформировался заново.

# %%
list_of_tests = gis_qa_qc.get_list_of_tests()
list_of_tests
# Out:
# ['test_missing_intervals',
#  'test_physical_correctness',
#  'test_repeat',
#  'test_surface_bounds_incoming']

# %%
result = gis_qa_qc.start_tests(list_of_tests)
# Out:
#      Тест пройден успешно.
#      "DS": пропуски в данных отсутствуют
# ------------------------------------------------------------------------------------
#
#      Тест пройден успешно.
#      "DT": пропуски в данных отсутствуют
# ------------------------------------------------------------------------------------
#
#      Тест пройден успешно.
#      "GR": пропуски в данных отсутствуют
# ------------------------------------------------------------------------------------
#
#      Тест пройден успешно.
#      "GZ1": пропуски в данных отсутствуют
# ------------------------------------------------------------------------------------
#
#      Тест пройден успешно.
#      "GZ2": пропуски в данных отсутствуют
# ------------------------------------------------------------------------------------
#
#      Тест пройден успешно.
#      "GZ3": пропуски в данных отсутствуют
# ------------------------------------------------------------------------------------
#
#      Тест пройден успешно.
# ...

# %% [markdown]
# Тест для оценки физичености кривых ГИС. Значения должны ложиться в заданный дмапозон

# %%
gis_qa_qc.test_physical_correctness()
# Out:
#      Тест пройден успешно.
#      Значения коротажа DS физически корректны
# ------------------------------------------------------------------------------------
#
#      Тест не был запущен.
#      Неизвестная размерность данных ms/m для DT
# ------------------------------------------------------------------------------------
#
#      Тест пройден успешно.
#      Значения коротажа GR физически корректны (Внимание, для этого ГИС проводилась проверка только на положительность значений)
# ------------------------------------------------------------------------------------
#
#      Тест пройден успешно.
#      Значения коротажа ILD физически корректны (Внимание, для этого ГИС проводилась проверка только на положительность значений)
# ------------------------------------------------------------------------------------
#
#      Тест пройден успешно.
#      Значения коротажа MGZ физически корректны (Внимание, для этого ГИС проводилась проверка только на положительность значений)
# ...

# %% [markdown]
# Оценка на наличие пропущенных интервалов в данных

# %%
gis_qa_qc.test_missing_intervals()
# Out:
#      Тест пройден успешно.
#      "DS": пропуски в данных отсутствуют
# ------------------------------------------------------------------------------------
#
#      Тест пройден успешно.
#      "DT": пропуски в данных отсутствуют
# ------------------------------------------------------------------------------------
#
#      Тест пройден успешно.
#      "GR": пропуски в данных отсутствуют
# ------------------------------------------------------------------------------------
#
#      Тест пройден успешно.
#      "GZ1": пропуски в данных отсутствуют
# ------------------------------------------------------------------------------------
#
#      Тест пройден успешно.
#      "GZ2": пропуски в данных отсутствуют
# ------------------------------------------------------------------------------------
#
#      Тест пройден успешно.
#      "GZ3": пропуски в данных отсутствуют
# ------------------------------------------------------------------------------------
#
#      Тест пройден успешно.
# ...

# %% [markdown]
# Оценка наличия дубликатов исследований ГИС в данных

# %%
gis_qa_qc.test_repeat()
# Out:
#      Тест пройден успешно.
#      Дубликатов ГИС в данных не найдено
# ------------------------------------------------------------------------------------
# {'file_name': '59P_OK_ft.las'}

# %% [markdown]
# Оценивает вхождение интервалов отбивок пластов в интервалы снятия ГИС

# %%
gis_qa_qc.test_surface_bounds_incoming()
# Out:
#      Тест не пройден.
#      Отметки пластопересечений не входят в интервал проведения ГИС
# ------------------------------------------------------------------------------------
# {'result': 'False', 'file_name': '59P_OK_ft.las'}

# %%
gis_qa_qc.generate_test_report(file_name='test_report_gis')

# %% [markdown]
# Второй порядок

# %%
path = 'data/gis_data/'

# %%
data_ok = pd.read_excel(path+'PoroOk.xlsx')
data_f = pd.read_excel(path+'PoroFail.xlsx')
poro_test(data_ok, data_f, 'Por', 'Porosity (open)')

# %%
data_rigis = pd.read_excel(path+'PermOK(B).xlsx')
data_kern = pd.read_excel(path+'PermFail(Q).xlsx')
perm_test(data_rigis, data_kern, 'Perm', 'Permeability, mkm2 (parallel)')

# %%
data_rigis = pd.read_excel(path+'PoroEffOK(B).xlsx')
data_kern = pd.read_excel(path+'PoroEffFail(N).xlsx')
poroeff_test(data_rigis, data_kern, 'PorEf', 'Porosity (effective)')

# %%
data_rigis = pd.read_excel(path+'PoroEffOK(B).xlsx')
data_kern = pd.read_excel(path+'PoroEffFail(N).xlsx')
lithology_test(data_rigis, data_kern, 'PorEf', 'Porosity (effective)')
