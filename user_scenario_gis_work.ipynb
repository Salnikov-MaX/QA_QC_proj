# %%
import lasio
import pandas as pd
import numpy as np
from qa_qc_lib.qa_qc_gis import QA_QC_gis

# %%
las_path = 'data/gis_data/59P_OK_ft.las'
gis_qa_qc = QA_QC_gis(las_path)
# Out:
# ВНИМАНИЕ! Не удалось распознать следующие каротажи: ['GZ1', 'GZ2', 'GZ3', 'GZ3R', 'GZ4', 'LLD', 'PZ']
#
#           Для того чтобы эти каротажи учавствовали в дальнейших тестах, следует расширить словарь мненмоник (используйте метод add_mnemonics),
#           а затем снова провести проверку, используя метод check_gis_names, чтобы список unidentified_gis сформировался заново.

# %%
kern_data = pd.read_excel('data/kern_data/Керн1.xlsx')
kern_data
# Out:
#            № скв Пласт Направление  Верх интервала отбора, м  \
# 0    9281 куст 5   НП4         кус                      2084
# 1    9281 куст 5   НП4         кус                      2084
# 2    9281 куст 5   НП4         кус                      2084
# 3    9281 куст 5   НП4         кус                      2084
# 4    9281 куст 5   НП4         пар                      2084
# ..           ...   ...         ...                       ...
# 496  9281 куст 5   НП4         кус                      2129
# 497  9281 куст 5   НП4         кус                      2129
# 498  9281 куст 5   НП4         кус                      2129
# 499  9281 куст 5   НП4         кус                      2129
# 500  9281 куст 5   НП4         кус                      2129
#
#      Низ интервала отбора, м  Вынос керна, м  Место взятия, м  \
# 0                       2102            18.0             0.36
# 1                       2102            18.0             0.36
# 2                       2102            18.0             0.62
# 3                       2102            18.0             0.62
# 4                       2102            18.0             0.82
# ..                       ...             ...              ...
# 496                     2147            18.0             7.65
# 497                     2147            18.0             7.80
# 498                     2147            18.0             8.41
# 499                     2147            18.0             9.84
# 500                     2147            18.0            10.29
#
#     Лабораторный номер образца  \
# 0                     24122-16
# 1                     24123-16
# 2                     24124-16
# 3                     24125-16
# 4                     24126-16
# ..                         ...
# 496                   24848-16
# 497                   24849-16
# 498                   24850-16
# 499                   24851-16
# 500                   24852-16
#
#                                Литологическое описание  Unnamed: 9  ...  \
# 0    Алевролит крупнозернистый, глинистый, с мелким...         0.0  ...
# 1    Алевролит крупнозернистый, глинистый, с мелким...         0.0  ...
# 2    Алевролит крупнозернистый, с мелкими линзочкам...         0.0  ...
# 3    Алевролит крупнозернистый, с мелкими линзочкам...         0.0  ...
# 4    Песчаник тонкозернистый, алевритовый, со слойк...         0.0  ...
# ..                                                 ...         ...  ...
# 496  Аргиллит алевритовый, с мелкими линзочками пес...         0.0  ...
# 497  Аргиллит алевритовый, с мелкими линзочками пес...         0.0  ...
# 498  Аргиллит алевритовый, с мелкими линзочками пес...         0.0  ...
# 499  Аргиллит алевритовый, с мелкими линзочками пес...         0.0  ...
# 500  Алевролит крупнозернистый, с мелкими линзочкам...         0.0  ...
#
#      Эффективная проницаемость, Кпр эф, мД  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ..                                     ...
# 496                                    NaN
# 497                                    NaN
# 498                                    NaN
# 499                                    NaN
# 500                                    NaN
#
#      Водоудерживающая способность, Квс, %  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# ..                                    ...
# 496                                   NaN
# 497                                   NaN
# 498                                   NaN
# 499                                   NaN
# 500                                   NaN
#
#      Остаточная водонасыщенность (ультрацентрифуга, Рк=18.7 атм.), Кво, %  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 496                                                NaN
# 497                                                NaN
# 498                                                NaN
# 499                                                NaN
# 500                                                NaN
#
#      Остаточная водонасыщенность (мембрана, Рк=12.0 атм.), Кво, %  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 496                                                NaN
# 497                                                NaN
# 498                                                NaN
# 499                                                NaN
# 500                                                NaN
#
#      Новый столбец  Объемная плотность, г/см3  \
# 0             2.41                       2.41
# 1             2.41                       2.41
# 2             2.43                       2.43
# 3             2.42                       2.42
# 4             2.30                       2.30
# ..             ...                        ...
# 496           2.41                       2.41
# 497           2.42                       2.42
# 498           2.42                       2.42
# 499           2.43                       2.43
# 500           2.43                       2.43
#
#      Кажущаяся минералогическая плотность, г/см3  Примечание  Смещение, м  \
# 0                                           2.72         NaN            1
# 1                                           2.72         NaN            1
# 2                                           2.71         NaN            1
# 3                                           2.71         NaN            1
# 4                                           2.72         NaN            1
# ..                                           ...         ...          ...
# 496                                         2.74         NaN            1
# 497                                         2.75         NaN            1
# 498                                         2.75         NaN            1
# 499                                         2.73         NaN            1
# 500                                         2.73         NaN            1
#
#      Глубина отбора образца после привязки к ГИС, м
# 0                                           2085.36
# 1                                           2085.36
# 2                                           2085.62
# 3                                           2085.62
# 4                                           2085.82
# ..                                              ...
# 496                                         2137.65
# 497                                         2137.80
# 498                                         2138.41
# 499                                         2139.84
# 500                                         2140.29
#
# [501 rows x 27 columns]
